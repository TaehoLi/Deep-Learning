# %%
'''
CNN to classify MNIST handwritten digits
'''
 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
 
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
 
# Read in MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/mnist", one_hot=True)
 
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10
 
# Network Parameters
n_input = 784 # input image shape = 28*28 grey scale
n_classes = 10 # 10 classes (0-9 digits)
dropout = 0.75 # probability to keep units during dropout
 
# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)
 
# Wrappers
def reshape(x, xdim, ydim):
    return tf.reshape(x, shape=[-1, xdim, ydim, 1])
 
def conv2d(x, W, b, stride=1):
    x = tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='SAME')
    return tf.nn.relu(x + b)
 
def maxpool2d(x, size=2, stride=2):
    return tf.nn.max_pool(x, ksize=[1, size, size, 1], strides=[1, stride, stride, 1], padding='SAME')
 
# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = reshape(x, 28, 28)
 
    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    print("Conv 1 = ", conv1)
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, size=2, stride=2)
    print("Conv 1 = ", conv1)
 
    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv1, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)
 
    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out
 
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # fully connected, ? inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([6272, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}
 
biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    ##'bc2': tf.Variable(tf.random_normal([?])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}
 
# Construct model
pred = conv_net(x, weights, biases, keep_prob)
 
# Define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
 
# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
 
# Launch the graph
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
 
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            l, acc = sess.run([loss, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(l) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
 
    # Calculate accuracy for 256 mnist test images
     
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256], keep_prob: 1.}))
    """
 
    correct_pred = tf.equal(tf.argmax(pred, axis=1), tf.argmax(y, axis=1))
    accuracy = tf.reduce_sum(tf.cast(correct_pred, tf.float32))
     
    n_batches = int(mnist.test.num_examples/batch_size)
    total_correct_pred = 0
     
    for i in range(n_batches):
        X_batch, Y_batch = mnist.test.next_batch(batch_size)
        accuracy_batch = sess.run(accuracy, feed_dict={x: X_batch, y:Y_batch, keep_prob: 1.}) 
        total_correct_pred += accuracy_batch   
     
    print('Accuracy {0}'.format(total_correct_pred/mnist.test.num_examples))
    """
# Out:
# WARNING:tensorflow:From <ipython-input-1-28fc4634ef8b>:14: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/mnist\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/mnist\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/mnist\t10k-images-idx3-ubyte.gz
# Extracting data/mnist\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Conv 1 =  Tensor("Relu:0", shape=(?, 28, 28, 32), dtype=float32)
# Conv 1 =  Tensor("MaxPool:0", shape=(?, 14, 14, 32), dtype=float32)
# WARNING:tensorflow:From <ipython-input-1-28fc4634ef8b>:61: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-1-28fc4634ef8b>:88: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Iter 1280, Minibatch Loss= 1025.516235, Training Accuracy= 0.37500
# Iter 2560, Minibatch Loss= 629.581421, Training Accuracy= 0.64062
# Iter 3840, Minibatch Loss= 206.035965, Training Accuracy= 0.81250
# Iter 5120, Minibatch Loss= 321.542908, Training Accuracy= 0.82031
# Iter 6400, Minibatch Loss= 209.191589, Training Accuracy= 0.84375
# Iter 7680, Minibatch Loss= 152.134750, Training Accuracy= 0.83594
# Iter 8960, Minibatch Loss= 252.016998, Training Accuracy= 0.89844
# Iter 10240, Minibatch Loss= 296.796692, Training Accuracy= 0.89062
# Iter 11520, Minibatch Loss= 228.457184, Training Accuracy= 0.89844
# Iter 12800, Minibatch Loss= 85.300690, Training Accuracy= 0.93750
# Iter 14080, Minibatch Loss= 138.575562, Training Accuracy= 0.88281
# Iter 15360, Minibatch Loss= 268.279785, Training Accuracy= 0.82031
# Iter 16640, Minibatch Loss= 112.849205, Training Accuracy= 0.90625
# Iter 17920, Minibatch Loss= 194.356506, Training Accuracy= 0.90625
# Iter 19200, Minibatch Loss= 59.290611, Training Accuracy= 0.94531
# Iter 20480, Minibatch Loss= 142.165405, Training Accuracy= 0.90625
# Iter 21760, Minibatch Loss= 91.950974, Training Accuracy= 0.92188
# Iter 23040, Minibatch Loss= 18.451206, Training Accuracy= 0.97656
# Iter 24320, Minibatch Loss= 155.817764, Training Accuracy= 0.85938
# Iter 25600, Minibatch Loss= 161.241547, Training Accuracy= 0.88281
# Iter 26880, Minibatch Loss= 51.943119, Training Accuracy= 0.94531
# Iter 28160, Minibatch Loss= 112.283661, Training Accuracy= 0.90625
# Iter 29440, Minibatch Loss= 67.017906, Training Accuracy= 0.93750
# Iter 30720, Minibatch Loss= 77.055305, Training Accuracy= 0.91406
# Iter 32000, Minibatch Loss= 33.637959, Training Accuracy= 0.95312
# Iter 33280, Minibatch Loss= 104.754959, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 114.366356, Training Accuracy= 0.90625
# Iter 35840, Minibatch Loss= 63.935814, Training Accuracy= 0.95312
# Iter 37120, Minibatch Loss= 105.760452, Training Accuracy= 0.90625
# Iter 38400, Minibatch Loss= 116.682716, Training Accuracy= 0.92188
# Iter 39680, Minibatch Loss= 36.190262, Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 57.379723, Training Accuracy= 0.93750
# Iter 42240, Minibatch Loss= 80.893616, Training Accuracy= 0.92969
# Iter 43520, Minibatch Loss= 30.229500, Training Accuracy= 0.96875
# Iter 44800, Minibatch Loss= 81.620361, Training Accuracy= 0.91406
# Iter 46080, Minibatch Loss= 29.005356, Training Accuracy= 0.94531
# Iter 47360, Minibatch Loss= 17.390268, Training Accuracy= 0.96094
# Iter 48640, Minibatch Loss= 57.310516, Training Accuracy= 0.93750
# Iter 49920, Minibatch Loss= 42.162876, Training Accuracy= 0.92188
# Iter 51200, Minibatch Loss= 137.266006, Training Accuracy= 0.92188
# Iter 52480, Minibatch Loss= 40.218758, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 63.349056, Training Accuracy= 0.94531
# Iter 55040, Minibatch Loss= 65.441483, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 84.737953, Training Accuracy= 0.92969
# Iter 57600, Minibatch Loss= 67.154556, Training Accuracy= 0.93750
# Iter 58880, Minibatch Loss= 21.025021, Training Accuracy= 0.93750
# Iter 60160, Minibatch Loss= 33.258862, Training Accuracy= 0.95312
# Iter 61440, Minibatch Loss= 32.653793, Training Accuracy= 0.95312
# Iter 62720, Minibatch Loss= 79.255241, Training Accuracy= 0.91406
# Iter 64000, Minibatch Loss= 47.282501, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 7.228341, Training Accuracy= 0.96875
# Iter 66560, Minibatch Loss= 15.298811, Training Accuracy= 0.97656
# Iter 67840, Minibatch Loss= 48.759575, Training Accuracy= 0.93750
# Iter 69120, Minibatch Loss= 12.076779, Training Accuracy= 0.96094
# Iter 70400, Minibatch Loss= 8.261469, Training Accuracy= 0.97656
# Iter 71680, Minibatch Loss= 81.373085, Training Accuracy= 0.92188
# Iter 72960, Minibatch Loss= 41.710815, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 28.716957, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 12.824085, Training Accuracy= 0.96875
# Iter 76800, Minibatch Loss= 44.352200, Training Accuracy= 0.95312
# Iter 78080, Minibatch Loss= 20.822706, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 53.888947, Training Accuracy= 0.90625
# Iter 80640, Minibatch Loss= 36.745285, Training Accuracy= 0.95312
# Iter 81920, Minibatch Loss= 70.374954, Training Accuracy= 0.94531
# Iter 83200, Minibatch Loss= 34.947182, Training Accuracy= 0.96875
# Iter 84480, Minibatch Loss= 61.312260, Training Accuracy= 0.92188
# Iter 85760, Minibatch Loss= 41.814674, Training Accuracy= 0.93750
# Iter 87040, Minibatch Loss= 53.001690, Training Accuracy= 0.93750
# Iter 88320, Minibatch Loss= 53.892208, Training Accuracy= 0.95312
# Iter 89600, Minibatch Loss= 7.106561, Training Accuracy= 0.97656
# Iter 90880, Minibatch Loss= 38.852058, Training Accuracy= 0.96094
# Iter 92160, Minibatch Loss= 41.411030, Training Accuracy= 0.92969
# Iter 93440, Minibatch Loss= 17.401443, Training Accuracy= 0.94531
# Iter 94720, Minibatch Loss= 29.074516, Training Accuracy= 0.94531
# Iter 96000, Minibatch Loss= 50.349682, Training Accuracy= 0.92188
# Iter 97280, Minibatch Loss= 37.195633, Training Accuracy= 0.96094
# Iter 98560, Minibatch Loss= 28.299099, Training Accuracy= 0.94531
# Iter 99840, Minibatch Loss= 40.907036, Training Accuracy= 0.94531
# Iter 101120, Minibatch Loss= 5.620162, Training Accuracy= 0.98438
# Iter 102400, Minibatch Loss= 19.402872, Training Accuracy= 0.94531
# Iter 103680, Minibatch Loss= 31.685959, Training Accuracy= 0.94531
# Iter 104960, Minibatch Loss= 18.168179, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 3.728909, Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 56.071602, Training Accuracy= 0.92969
# Iter 108800, Minibatch Loss= 29.227388, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 11.991895, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 20.549181, Training Accuracy= 0.95312
# Iter 112640, Minibatch Loss= 7.809162, Training Accuracy= 0.96094
# Iter 113920, Minibatch Loss= 49.128830, Training Accuracy= 0.94531
# Iter 115200, Minibatch Loss= 17.781204, Training Accuracy= 0.97656
# Iter 116480, Minibatch Loss= 32.740120, Training Accuracy= 0.96094
# Iter 117760, Minibatch Loss= 14.455596, Training Accuracy= 0.96094
# Iter 119040, Minibatch Loss= 22.770958, Training Accuracy= 0.96094
# Iter 120320, Minibatch Loss= 28.551657, Training Accuracy= 0.97656
# Iter 121600, Minibatch Loss= 7.714152, Training Accuracy= 0.98438
# Iter 122880, Minibatch Loss= 5.788127, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 6.181455, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 11.108471, Training Accuracy= 0.96094
# Iter 126720, Minibatch Loss= 6.754603, Training Accuracy= 0.96094
# Iter 128000, Minibatch Loss= 11.085361, Training Accuracy= 0.97656
# Iter 129280, Minibatch Loss= 23.275286, Training Accuracy= 0.97656
# Iter 130560, Minibatch Loss= 4.575415, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 34.874336, Training Accuracy= 0.94531
# Iter 133120, Minibatch Loss= 25.168770, Training Accuracy= 0.95312
# Iter 134400, Minibatch Loss= 14.944389, Training Accuracy= 0.96094
# Iter 135680, Minibatch Loss= 10.798424, Training Accuracy= 0.96875
# Iter 136960, Minibatch Loss= 29.861212, Training Accuracy= 0.96875
# Iter 138240, Minibatch Loss= 31.564110, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 9.348451, Training Accuracy= 0.97656
# Iter 140800, Minibatch Loss= 21.936584, Training Accuracy= 0.93750
# Iter 142080, Minibatch Loss= 23.699978, Training Accuracy= 0.95312
# Iter 143360, Minibatch Loss= 4.827573, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 18.520632, Training Accuracy= 0.94531
# Iter 145920, Minibatch Loss= 44.388992, Training Accuracy= 0.92188
# Iter 147200, Minibatch Loss= 8.676874, Training Accuracy= 0.98438
# Iter 148480, Minibatch Loss= 28.792557, Training Accuracy= 0.96094
# Iter 149760, Minibatch Loss= 4.290674, Training Accuracy= 0.96875
# Iter 151040, Minibatch Loss= 34.082436, Training Accuracy= 0.95312
# Iter 152320, Minibatch Loss= 7.784773, Training Accuracy= 0.96094
# Iter 153600, Minibatch Loss= 4.089704, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 8.879371, Training Accuracy= 0.96875
# Iter 156160, Minibatch Loss= 5.548431, Training Accuracy= 0.97656
# Iter 157440, Minibatch Loss= 21.551687, Training Accuracy= 0.96875
# Iter 158720, Minibatch Loss= 34.108429, Training Accuracy= 0.95312
# Iter 160000, Minibatch Loss= 5.246013, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 162560, Minibatch Loss= 15.619555, Training Accuracy= 0.96094
# Iter 163840, Minibatch Loss= 24.692459, Training Accuracy= 0.96094
# Iter 165120, Minibatch Loss= 29.285763, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 42.697861, Training Accuracy= 0.96094
# Iter 167680, Minibatch Loss= 10.485561, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 170240, Minibatch Loss= 10.209953, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 6.298216, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 1.734828, Training Accuracy= 0.98438
# Iter 174080, Minibatch Loss= 6.057553, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 15.066736, Training Accuracy= 0.96875
# Iter 176640, Minibatch Loss= 2.385541, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 9.394919, Training Accuracy= 0.96875
# Iter 179200, Minibatch Loss= 10.258162, Training Accuracy= 0.97656
# Iter 180480, Minibatch Loss= 3.618824, Training Accuracy= 0.97656
# Iter 181760, Minibatch Loss= 10.757561, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 19.098053, Training Accuracy= 0.95312
# Iter 184320, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 185600, Minibatch Loss= 0.855209, Training Accuracy= 0.99219
# Iter 186880, Minibatch Loss= 9.096026, Training Accuracy= 0.97656
# Iter 188160, Minibatch Loss= 2.798863, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 22.322178, Training Accuracy= 0.96094
# Iter 190720, Minibatch Loss= 2.294534, Training Accuracy= 0.98438
# Iter 192000, Minibatch Loss= 8.742308, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 16.171810, Training Accuracy= 0.92969
# Iter 194560, Minibatch Loss= 4.216105, Training Accuracy= 0.98438
# Iter 195840, Minibatch Loss= 3.492417, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 17.786236, Training Accuracy= 0.96094
# Iter 198400, Minibatch Loss= 8.343815, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 4.303733, Training Accuracy= 0.97656
# Optimization Finished!
# Testing Accuracy: 0.9765625

# %%
'''
CNN to classify MNIST handwritten digits
'''
 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
 
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
 
# Read in MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("data/mnist", one_hot=True)
 
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10
 
# Network Parameters
n_input = 784 # input image shape = 28*28 grey scale
n_classes = 10 # 10 classes (0-9 digits)
dropout = 0.75 # probability to keep units during dropout
 
# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) # dropout (keep probability)
 
# Wrappers
def reshape(x, xdim, ydim):
    return tf.reshape(x, shape=[-1, xdim, ydim, 1])
 
def conv2d(x, W, b, stride=1):
    x = tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding='SAME')
    return tf.nn.relu(x + b)
 
def maxpool2d(x, size=2, stride=2):
    return tf.nn.max_pool(x, ksize=[1, size, size, 1], strides=[1, stride, stride, 1], padding='SAME')
 
# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = reshape(x, 28, 28)
 
    # Convolution Layer 1
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    print("Conv 1 = ", conv1)
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, size=2, stride=2)
    print("Conv 1 = ", conv1)
    
    # Convolution Layer 2
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    print("Conv 2 = ", conv2)
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, size=2, stride=2)
    print("Conv 2 = ", conv2)
 
    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)
 
    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out
 
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, ? inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([3136, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}
 
biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}
 
# Construct model
pred = conv_net(x, weights, biases, keep_prob)
 
# Define loss and optimizer
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
 
# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
 
# Launch the graph
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
 
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            l, acc = sess.run([loss, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(l) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
 
    # Calculate accuracy for 256 mnist test images
     
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256], keep_prob: 1.}))
    """
 
    correct_pred = tf.equal(tf.argmax(pred, axis=1), tf.argmax(y, axis=1))
    accuracy = tf.reduce_sum(tf.cast(correct_pred, tf.float32))
     
    n_batches = int(mnist.test.num_examples/batch_size)
    total_correct_pred = 0
     
    for i in range(n_batches):
        X_batch, Y_batch = mnist.test.next_batch(batch_size)
        accuracy_batch = sess.run(accuracy, feed_dict={x: X_batch, y:Y_batch, keep_prob: 1.}) 
        total_correct_pred += accuracy_batch   
     
    print('Accuracy {0}'.format(total_correct_pred/mnist.test.num_examples))
    """
# Out:
# WARNING:tensorflow:From <ipython-input-1-2bbf78267399>:14: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/mnist\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting data/mnist\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting data/mnist\t10k-images-idx3-ubyte.gz
# Extracting data/mnist\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\my\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Conv 1 =  Tensor("Relu:0", shape=(?, 28, 28, 32), dtype=float32)
# Conv 1 =  Tensor("MaxPool:0", shape=(?, 14, 14, 32), dtype=float32)
# Conv 2 =  Tensor("Relu_1:0", shape=(?, 14, 14, 64), dtype=float32)
# Conv 2 =  Tensor("MaxPool_1:0", shape=(?, 7, 7, 64), dtype=float32)
# WARNING:tensorflow:From <ipython-input-1-2bbf78267399>:68: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From <ipython-input-1-2bbf78267399>:96: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# Iter 1280, Minibatch Loss= 30994.375000, Training Accuracy= 0.21094
# Iter 2560, Minibatch Loss= 9480.238281, Training Accuracy= 0.57031
# Iter 3840, Minibatch Loss= 7479.869141, Training Accuracy= 0.68750
# Iter 5120, Minibatch Loss= 5415.143066, Training Accuracy= 0.73438
# Iter 6400, Minibatch Loss= 4666.048340, Training Accuracy= 0.77344
# Iter 7680, Minibatch Loss= 6122.008301, Training Accuracy= 0.78906
# Iter 8960, Minibatch Loss= 2916.581543, Training Accuracy= 0.85938
# Iter 10240, Minibatch Loss= 2793.807129, Training Accuracy= 0.86719
# Iter 11520, Minibatch Loss= 4152.298340, Training Accuracy= 0.78906
# Iter 12800, Minibatch Loss= 2783.802734, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 2854.904297, Training Accuracy= 0.87500
# Iter 15360, Minibatch Loss= 2549.602539, Training Accuracy= 0.89844
# Iter 16640, Minibatch Loss= 1832.645020, Training Accuracy= 0.92188
# Iter 17920, Minibatch Loss= 1517.274902, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 2199.563477, Training Accuracy= 0.89844
# Iter 20480, Minibatch Loss= 1147.352905, Training Accuracy= 0.91406
# Iter 21760, Minibatch Loss= 1296.320923, Training Accuracy= 0.91406
# Iter 23040, Minibatch Loss= 1089.216431, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 2027.300659, Training Accuracy= 0.87500
# Iter 25600, Minibatch Loss= 240.438843, Training Accuracy= 0.95312
# Iter 26880, Minibatch Loss= 1315.468506, Training Accuracy= 0.90625
# Iter 28160, Minibatch Loss= 1618.170654, Training Accuracy= 0.92188
# Iter 29440, Minibatch Loss= 1914.907227, Training Accuracy= 0.89844
# Iter 30720, Minibatch Loss= 1565.464600, Training Accuracy= 0.89844
# Iter 32000, Minibatch Loss= 1163.073242, Training Accuracy= 0.93750
# Iter 33280, Minibatch Loss= 1415.321777, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 1825.793457, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 976.614136, Training Accuracy= 0.92969
# Iter 37120, Minibatch Loss= 1191.479248, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 1348.757690, Training Accuracy= 0.92969
# Iter 39680, Minibatch Loss= 526.794983, Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 291.236450, Training Accuracy= 0.96875
# Iter 42240, Minibatch Loss= 974.990051, Training Accuracy= 0.92188
# Iter 43520, Minibatch Loss= 1357.744995, Training Accuracy= 0.92969
# Iter 44800, Minibatch Loss= 822.038696, Training Accuracy= 0.90625
# Iter 46080, Minibatch Loss= 1610.388916, Training Accuracy= 0.89844
# Iter 47360, Minibatch Loss= 545.394409, Training Accuracy= 0.95312
# Iter 48640, Minibatch Loss= 1653.703369, Training Accuracy= 0.92188
# Iter 49920, Minibatch Loss= 512.372681, Training Accuracy= 0.96875
# Iter 51200, Minibatch Loss= 568.570923, Training Accuracy= 0.93750
# Iter 52480, Minibatch Loss= 256.547791, Training Accuracy= 0.97656
# Iter 53760, Minibatch Loss= 1294.751831, Training Accuracy= 0.92188
# Iter 55040, Minibatch Loss= 2071.816406, Training Accuracy= 0.93750
# Iter 56320, Minibatch Loss= 195.366150, Training Accuracy= 0.96875
# Iter 57600, Minibatch Loss= 1151.066406, Training Accuracy= 0.92188
# Iter 58880, Minibatch Loss= 419.615692, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 1080.598389, Training Accuracy= 0.94531
# Iter 61440, Minibatch Loss= 770.357422, Training Accuracy= 0.94531
# Iter 62720, Minibatch Loss= 1276.888428, Training Accuracy= 0.90625
# Iter 64000, Minibatch Loss= 1222.508179, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 392.480164, Training Accuracy= 0.94531
# Iter 66560, Minibatch Loss= 487.940063, Training Accuracy= 0.96875
# Iter 67840, Minibatch Loss= 551.983582, Training Accuracy= 0.94531
# Iter 69120, Minibatch Loss= 868.184631, Training Accuracy= 0.92969
# Iter 70400, Minibatch Loss= 841.799316, Training Accuracy= 0.95312
# Iter 71680, Minibatch Loss= 389.255554, Training Accuracy= 0.94531
# Iter 72960, Minibatch Loss= 912.215027, Training Accuracy= 0.93750
# Iter 74240, Minibatch Loss= 179.536591, Training Accuracy= 0.96094
# Iter 75520, Minibatch Loss= 253.899750, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 69.529861, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 358.909180, Training Accuracy= 0.96875
# Iter 79360, Minibatch Loss= 364.571289, Training Accuracy= 0.95312
# Iter 80640, Minibatch Loss= 580.003784, Training Accuracy= 0.96094
# Iter 81920, Minibatch Loss= 144.421906, Training Accuracy= 0.96094
# Iter 83200, Minibatch Loss= 57.014511, Training Accuracy= 0.98438
# Iter 84480, Minibatch Loss= 503.362854, Training Accuracy= 0.97656
# Iter 85760, Minibatch Loss= 65.314651, Training Accuracy= 0.96875
# Iter 87040, Minibatch Loss= 252.993683, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 493.691223, Training Accuracy= 0.95312
# Iter 89600, Minibatch Loss= 492.209106, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 847.580627, Training Accuracy= 0.94531
# Iter 92160, Minibatch Loss= 612.770020, Training Accuracy= 0.95312
# Iter 93440, Minibatch Loss= 606.755005, Training Accuracy= 0.93750
# Iter 94720, Minibatch Loss= 20.066895, Training Accuracy= 0.98438
# Iter 96000, Minibatch Loss= 299.241577, Training Accuracy= 0.96094
# Iter 97280, Minibatch Loss= 597.132812, Training Accuracy= 0.92969
# Iter 98560, Minibatch Loss= 93.272621, Training Accuracy= 0.96094
# Iter 99840, Minibatch Loss= 324.234985, Training Accuracy= 0.95312
# Iter 101120, Minibatch Loss= 189.125305, Training Accuracy= 0.98438
# Iter 102400, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 103680, Minibatch Loss= 725.855591, Training Accuracy= 0.97656
# Iter 104960, Minibatch Loss= 378.843689, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 192.110825, Training Accuracy= 0.97656
# Iter 107520, Minibatch Loss= 567.986877, Training Accuracy= 0.96875
# Iter 108800, Minibatch Loss= 468.246460, Training Accuracy= 0.93750
# Iter 110080, Minibatch Loss= 438.179169, Training Accuracy= 0.95312
# Iter 111360, Minibatch Loss= 484.348877, Training Accuracy= 0.95312
# Iter 112640, Minibatch Loss= 429.746490, Training Accuracy= 0.96094
# Iter 113920, Minibatch Loss= 221.919754, Training Accuracy= 0.97656
# Iter 115200, Minibatch Loss= 227.378189, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 263.348938, Training Accuracy= 0.96094
# Iter 117760, Minibatch Loss= 482.947876, Training Accuracy= 0.96875
# Iter 119040, Minibatch Loss= 295.612091, Training Accuracy= 0.96094
# Iter 120320, Minibatch Loss= 252.313400, Training Accuracy= 0.97656
# Iter 121600, Minibatch Loss= 416.775635, Training Accuracy= 0.96094
# Iter 122880, Minibatch Loss= 226.677521, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 435.260437, Training Accuracy= 0.97656
# Iter 125440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 126720, Minibatch Loss= 199.330719, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 526.375427, Training Accuracy= 0.95312
# Iter 129280, Minibatch Loss= 214.706070, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 335.378571, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 365.451660, Training Accuracy= 0.96094
# Iter 133120, Minibatch Loss= 191.008484, Training Accuracy= 0.96094
# Iter 134400, Minibatch Loss= 283.351227, Training Accuracy= 0.97656
# Iter 135680, Minibatch Loss= 482.730591, Training Accuracy= 0.96094
# Iter 136960, Minibatch Loss= 137.299026, Training Accuracy= 0.98438
# Iter 138240, Minibatch Loss= 243.257294, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 414.650452, Training Accuracy= 0.94531
# Iter 140800, Minibatch Loss= 461.050262, Training Accuracy= 0.96094
# Iter 142080, Minibatch Loss= 118.414772, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 71.700851, Training Accuracy= 0.96875
# Iter 144640, Minibatch Loss= 125.210335, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 70.804771, Training Accuracy= 0.98438
# Iter 147200, Minibatch Loss= 157.037994, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 437.381073, Training Accuracy= 0.96094
# Iter 149760, Minibatch Loss= 184.281952, Training Accuracy= 0.97656
# Iter 151040, Minibatch Loss= 12.537628, Training Accuracy= 0.98438
# Iter 152320, Minibatch Loss= 27.379761, Training Accuracy= 0.98438
# Iter 153600, Minibatch Loss= 368.316742, Training Accuracy= 0.93750
# Iter 154880, Minibatch Loss= 320.416077, Training Accuracy= 0.97656
# Iter 156160, Minibatch Loss= 482.610992, Training Accuracy= 0.92969
# Iter 157440, Minibatch Loss= 60.255653, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 268.189636, Training Accuracy= 0.95312
# Iter 160000, Minibatch Loss= 53.908699, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 33.027100, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 85.437958, Training Accuracy= 0.97656
# Iter 163840, Minibatch Loss= 301.271332, Training Accuracy= 0.95312
# Iter 165120, Minibatch Loss= 328.427582, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 53.576935, Training Accuracy= 0.97656
# Iter 167680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 168960, Minibatch Loss= 14.309692, Training Accuracy= 0.99219
# Iter 170240, Minibatch Loss= 63.496925, Training Accuracy= 0.98438
# Iter 171520, Minibatch Loss= 135.355988, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 326.913605, Training Accuracy= 0.96094
# Iter 174080, Minibatch Loss= 47.653454, Training Accuracy= 0.98438
# Iter 175360, Minibatch Loss= 113.800545, Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 65.151474, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 22.607941, Training Accuracy= 0.99219
# Iter 179200, Minibatch Loss= 20.598061, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 217.496796, Training Accuracy= 0.94531
# Iter 181760, Minibatch Loss= 42.841370, Training Accuracy= 0.99219
# Iter 183040, Minibatch Loss= 63.479584, Training Accuracy= 0.99219
# Iter 184320, Minibatch Loss= 302.532196, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 159.191254, Training Accuracy= 0.95312
# Iter 186880, Minibatch Loss= 121.476250, Training Accuracy= 0.96875
# Iter 188160, Minibatch Loss= 181.831131, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 292.411163, Training Accuracy= 0.98438
# Iter 190720, Minibatch Loss= 49.018463, Training Accuracy= 0.99219
# Iter 192000, Minibatch Loss= 182.617538, Training Accuracy= 0.96875
# Iter 193280, Minibatch Loss= 138.149933, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 243.119385, Training Accuracy= 0.98438
# Iter 195840, Minibatch Loss= 87.156708, Training Accuracy= 0.98438
# Iter 197120, Minibatch Loss= 254.726135, Training Accuracy= 0.94531
# Iter 198400, Minibatch Loss= 43.727684, Training Accuracy= 0.98438
# Iter 199680, Minibatch Loss= 211.653687, Training Accuracy= 0.96875
# Optimization Finished!
# Testing Accuracy: 0.984375
